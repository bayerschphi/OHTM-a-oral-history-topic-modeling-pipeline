# %%
# !git clone https://github.com/bayerschphi/ohtm_pipeline

# %cd ohtm_pipeline
# %pip install -r requirements.txt
# !pip install -e .

# %% [markdown]
# # OHTM a oral history topic modeling pipeline

# %% [markdown]
#  ### Philipp  Bayerschmidt [![orcid](https://orcid.org/sites/default/files/images/orcid_16x16.png)](https://orcid.org/0009-0002-2743-2455)
# Institution

# %%
[![cc-by](https://licensebuttons.net/l/by/4.0/88x31.png)](https://creativecommons.org/licenses/by/4.0/) 
©<AUTHOR or ORGANIZATION / FUNDER>. Published by De Gruyter in cooperation with the University of Luxembourg Centre for Contemporary and Digital History. This is an Open Access article distributed under the terms of the [Creative Commons Attribution License CC-BY](https://creativecommons.org/licenses/by/4.0/)

# %% [markdown]
# [![cc-by-nc-nd](https://licensebuttons.net/l/by-nc-nd/4.0/88x31.png)](https://creativecommons.org/licenses/by-nc-nd/4.0/)
# ©<AUTHOR or ORGANIZATION / FUNDER>. Published by De Gruyter in cooperation with the University of Luxembourg Centre for Contemporary and Digital History. This is an Open Access article distributed under the terms of the [Creative Commons Attribution License CC-BY-NC-ND](https://creativecommons.org/licenses/by-nc-nd/4.0/)

# %%
# from IPython.display import Image, display
# display(Image("./media/placeholder.png"))

# %% [markdown]
# This is an abstract (...)

# %% [markdown]
# # Introduction

# %% [markdown]
# A relevant field of study is the process of arriving and making home of people, settling to Germany after 1945 and deciding to stay permanently. How is the idea of “Heimat” (home) transformed to the new home and what helps or restrains that process? Narrative interviews are a complex and multilayered source and offer interesting approaches to a concept like home, since interviewees refer to their home-making in many different forms. They are therefore promising source material for the re-use of existing research data. Nevertheless, these references are hard to find just with key words or other simple approaches to search, since the concept is complex and seldom referred to directly. Narrative interviews were hard to find, because they were spread across many different archives, research institutions and researchers. Within the DFG-funded project "Oral-History.Digital" there are a large number of interviews from a wide variety of holdings that have been digitized and are accessible online.

# %% [markdown]
# # Concept of "Heimat"

# %% [markdown]
# # OHTM-Pipeline

# %% [markdown]
# The solution was to build my own topic modeling pipeline the “Oral History Topic Modeling Pipeline” (OHTM-Pipeline). For this I created a special data structure, a single file, that contains each interview of my corpus in a unique way to retain all necessary information. The pipeline creates the data structure and performs all the necessary steps of topic modeling by reading the relevant data from this data structure and storing it in it. In the end you have a single file that contains not only the hole corpus, but also all preprocessed texts, the results of topic modeling, and the settings and variables of the topic modeling process.
# I needed topic modeling not only for describing my corpus but for finding the traces of special topics and how they were combined. The approach was put into a pipeline. This structure makes it possible to analyze the results in different ways. For example, a bar chart can provide information on how the topics are weighed across the entire corpus, while a heat map shows the distribution of topics across each individual interview. Both the bar chart and the heat map can be filtered according to individual archives in order to examine the priority areas and differences in topic weighting in the various archives. The individual interviews can also be analyzed using a heat map by displaying the topic distribution across the individual chunks in chronological order. In addition, the entire corpus as well as individual interviews can be searched for specific topics and weightings. In theory, the data can be published and offers transparent access to my research data and results.

# %% [markdown]
# ## Topic Modeling als Methode

# %% [markdown]
# ## Pipeline Structure

# %% [markdown]
# ## Datastructure

# %% [markdown]
# The data frame is structured as a nested dictionary to create different levels of depth, to store the information on the right levels. The lowest level is the single sentence of an interview. For the sentence I save the original text, the processed or cleaned text, the speaker, the timecode, and the chunk it will be in. On the next level I assign a number to every sentence representing the order of the sentences inside the original document. With the numbers I can create the original text with my saved sentences. The next level is the interview id or file name the level above is the archive in which the interview is in. That information builds up my corpus. This is the highest level in the data frame. On the same level I have two entries that contain the results of topic modeling. First, I save the distribution of the topics for every chunk and second, I save the word lists of the calculated topics. Another entry contains the list of stop words that were removed. And the last entry saves all the settings of every processed step.

# %%
from IPython.display import Image, display
display(Image("./media/ohtm_file data structure.png"))

# %% [markdown]
# Corpus
# Stopwords
# Weight
# Words
# Settings

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Problems fo different text files and transkripts

# %% [markdown]
# ### Normalisierung und Eingriffe in den Text

# %% [markdown]
# ### Chunking

# %% [markdown]
# Why is chunking important...

# %% [markdown]
# Erklären, wie bisherige Pipelines das Problem angehen, dass chunking erst nach dem Preprocessing und vorallem nach dem entfernen von Stopwords stattfindet. Grund ist paragraphen oder Sinnzusammenhänge. Aber bei Interviews ist das eh nicht machbar. Problem von unterschiedlich langen chunks.

# %% [markdown]
# Betrachtet man die länge der einzelnen Sätze im Korpus wird deutlich, dass diese grundsätzlich alle ungefähr gleich lang sind. Aufgrund einer Importprobleme gibt es durchaus auch sehr lange sätze, die sind aber augrund der geringen Häufigkeit, mit der sie auftreten zunächst einmal zu vernachlässigen. <cite id="n5a7k"><a href="#zotero%7C20217732%2FSGLRC5IQ">(Burns, 2018)</a></cite>

# %% [markdown]
# ## Processing

# %% [markdown]
# ## Postprocessing

# %% [markdown]
# ### Topics, Weights and Chunks

# %%
from IPython.display import Image, display
display(Image("./media/raw_sent_length.png"))

# %% [markdown]
# ### Visualization

# %% [markdown]
# # Schluss

# %% [markdown]
# # Bibliographie

# %% [markdown]
# <!-- BIBLIOGRAPHY START -->
# <div class="csl-bib-body">
#   <div class="csl-entry"><i id="zotero|20217732/SGLRC5IQ"></i>Burns, P. J. (2018). Constructing Stoplists for Historical Languages. <i>Digital Classics Online</i>, <i>Bd. 4</i>, 4-20 Seiten. <a href="https://doi.org/10.11588/DCO.2018.2.52124">https://doi.org/10.11588/DCO.2018.2.52124</a></div>
# </div>
# <!-- BIBLIOGRAPHY END -->

# %%
"""
OHTM-Pipeline:

With this board you can select every option for your topic model.
You can set the different options on and off via "True" and "False".

First set the required paths.
    - the first "mallet_path" to your mallet directory.
     (see https://programminghistorian.org/en/lessons/topic-modeling-and-mallet)
    - the second one to your working folder. This folder is your working environment.
      All models are saved there and can be loaded from this folder.
    - your stopword file must be stored in this working folder.
"""

"""
This demo is used to test, if the code runs proper and is linked to the demo folder and its demo files.
- You can test importing the text files and preprocessing them. 
- You can print the prepared ohmt_files or create the graphs for this file or use the search functions
- Topic modeling is not able, because you need to install mallet first.
"""

from ohtm.pipeline import ohtm_pipeline_function
import os

''' Path Settings: '''
# Path to your mallet folder.
os.environ['MALLET_HOME'] = r'C:\\mallet-2.0.8' # does not work in the demo_main, just leave it, as it is
mallet_path: str = r'C:\mallet-2.0.8\bin\mallet' # does not work in the demo_main, just leave it, as it is


# Path to your output_folder.
output_folder: str = (r"ohtm_pipeline/Demo")

# Set the path for your stop_word list.
stopword_file_name = "german_stopwords_standard.txt"

# Set the path to your sources. This must be the folder, where your documents are stored in another folder.
source_path: str = (r"Demo\demo_interviews")

source_folder = ["archive_1", "archive_2", "txt_files"]

""" Topic Modeling Settings: """

load_ohtm_file = True
load_file_name = "demo_ohtm_file_trained"

create_ohtm_file = False
save_ohtm_file = False
save_name = "demo_ohtm_file_trained"

# You need to set a save_name and set the option save_json to True to save the model
save_model = False # does not work in the demo_main, just leave it, as it is

use_preprocessing = False

# If you don't want to chunk your documents, set use_chunking to True and chunk_setting to 0
use_chunking = False
chunk_setting = 20

use_topic_modeling = False # does not work in the demo_main, just leave it, as it is
topics = 10 # does not work in the demo_main, just leave it, as it is

save_top_words = True
number_of_words = 20

print_ohtm_file = True
print_ohtm_file_settings = True
show_bar_graph_corpus = True
show_heatmap_corpus = True

interview_id = "abc0001"
chunk_number = 0
show_heatmap_interview = False
print_interview_chunk = True
search_for_topics_in_chunks = True
topic_search = 0
chunk_weight = 0.2
search_for_topics_in_interview = True

''' advanced options: '''

# topic_modeling
optimize_interval_mallet = 50
iterations_mallet = 500
alpha = 5
random_seed = 80

# ohtm_file creation
speaker_txt = True
folder_as_archive = False

# preprocessing
# Select just one of those two:
stopword_removal_by_stop_list = True

# To use this options, you have to select a valid spacy model:
stopword_removal_by_spacy = False # does not work in the demo_main, just leave it, as it is
use_lemmatization = False # does not work in the demo_main, just leave it, as it is
lemmatization_model_spacy = "de_core_news_lg" # does not work in the demo_main, just leave it, as it is
use_pos_filter = False # does not work in the demo_main, just leave it, as it is

# possible settings: 'NOUN', 'PROPN', 'VERB', 'ADJ', 'ADV', 'PRON', 'ADP', 'DET', 'AUX', 'NUM', 'SCONJ', 'CCONJ', 'X'
allowed_postags_settings_lemmatization = ['NOUN', 'PROPN', 'VERB', 'ADJ', 'NUM', 'ADV']

''' Inferring new documents with an trained topic model'''

infer_new_documents = False
trained_ohtm_file = "...."  # load the trained json and the model to train that json
save_separate_ohtm_file = False  # save the inferred documents as a new json
separate_ohtm_file_name = "...."


if __name__ == "__main__":
    ohtm_pipeline_function(
        output_folder=output_folder,
        source_folder=source_folder,
        source_path=source_path,
        stopword_file_name=stopword_file_name,
        allowed_postags_settings=allowed_postags_settings_lemmatization,
        save_name=save_name,
        load_file_name=load_file_name,
        mallet_path= mallet_path,
        interview_id=interview_id,
        chunk_setting=chunk_setting,
        topics=topics,
        number_of_words=number_of_words,
        chunk_number=chunk_number,
        topic_search=topic_search,
        chunk_weight=chunk_weight,
        optimize_interval_mallet=optimize_interval_mallet,
        iterations_mallet=iterations_mallet,
        alpha=alpha,
        random_seed=random_seed,
        save_ohtm_file=save_ohtm_file,
        create_ohtm_file=create_ohtm_file,
        load_ohtm_file=load_ohtm_file,
        use_preprocessing=use_preprocessing,
        use_chunking=use_chunking,
        use_topic_modeling=use_topic_modeling,
        save_top_words=save_top_words,
        print_ohtm_file=print_ohtm_file,
        show_bar_graph_corpus=show_bar_graph_corpus,
        show_heatmap_corpus=show_heatmap_corpus,
        show_heatmap_interview=show_heatmap_interview,
        print_interview_chunk=print_interview_chunk,
        search_for_topics_in_chunks=search_for_topics_in_chunks,
        search_for_topics_in_interview=search_for_topics_in_interview,
        by_list=stopword_removal_by_stop_list,
        pos_filter_setting=use_pos_filter,
        lemma=use_lemmatization,
        save_model=save_model,
        infer_new_documents=infer_new_documents,
        trained_ohtm_file=trained_ohtm_file,
        save_separate_ohtm_file=save_separate_ohtm_file,
        separate_ohtm_file_name=separate_ohtm_file_name,
        speaker_txt=speaker_txt,
        folder_as_archive=folder_as_archive,
        print_ohtm_file_settings=print_ohtm_file_settings,
        spacy_model_name=lemmatization_model_spacy,
        stopword_removal_by_spacy=stopword_removal_by_spacy
    )

# %%
# !cd
# Out:
# C:\Users\phili\Documents\GitHub\OHTM-a-oral-history-topic-modeling-pipeline
